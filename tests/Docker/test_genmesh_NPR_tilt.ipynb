# %%
from fenics import *
from dolfin_adjoint import *
import pygmsh_mesh_functions
from pygmsh_mesh_functions import *
import meshio
import numpy as np
import matplotlib.pyplot as plt

# %%
def hole_NPR(domain, c, l, theta, margin = 0.05):
    co, so = np.cos(theta), np.sin(theta)
    Rotation = np.array(((co, -so), (so, co)))
    shift_l = np.matmul(Rotation,np.array([-1,0]))
    shift_r = np.matmul(Rotation,np.array([ 1,0]))
    ell_c = add_ellipse(c, (1-margin)*np.sqrt(1/2)*l, (1-margin)*np.sqrt(1/2)*l)
    ell_l = add_ellipse(c+shift_l*l, (1+margin)*np.sqrt(1/2)*l, (1+margin)*np.sqrt(1/2)*l)
    ell_r = add_ellipse(c+shift_r*l, (1+margin)*np.sqrt(1/2)*l, (1+margin)*np.sqrt(1/2)*l)
    tool = subtract(ell_c, ell_l)
    tool = subtract(tool, ell_r)
    domain = subtract(domain, tool)
    
def hole_NPR_rounded(domain, c, l, theta, margin = 0.05):
    co, so = np.cos(theta), np.sin(theta)
    Rotation = np.array(((co, -so), (so, co)))
    scale = 1+np.sqrt(2)
    shift_l = np.matmul(Rotation,np.array([-1,0]))/scale
    shift_r = np.matmul(Rotation,np.array([ 1,0]))/scale
    shift_u = np.matmul(Rotation,np.array([0, 1]))/scale
    shift_d = np.matmul(Rotation,np.array([0,-1]))/scale
    ell_c = add_ellipse(c, (1)*np.sqrt(1/2)*l/scale, (1)*np.sqrt(1/2)*l/scale)
    ell_u = add_ellipse(c+shift_u*l, (1-margin)*np.sqrt(1/2)*l/scale, (1-margin)*np.sqrt(1/2)*l/scale)
    ell_d = add_ellipse(c+shift_d*l, (1-margin)*np.sqrt(1/2)*l/scale, (1-margin)*np.sqrt(1/2)*l/scale)
    ell_l = add_ellipse(c+shift_l*l, (1+margin)*np.sqrt(1/2)*l/scale, (1+margin)*np.sqrt(1/2)*l/scale)
    ell_r = add_ellipse(c+shift_r*l, (1+margin)*np.sqrt(1/2)*l/scale, (1+margin)*np.sqrt(1/2)*l/scale)
    tool = union(ell_c, ell_u)
    tool = union(ell_c, ell_d)
    tool = subtract(tool, [ell_l,ell_r])
    domain = subtract(domain, tool)

def hole_concave(domain, c, l, theta, margin = 0.05):
    co, so = np.cos(theta), np.sin(theta)
    Rotation = np.array(((co, -so), (so, co)))
    shift_l = np.matmul(Rotation,np.array([-1,0]))
    shift_r = np.matmul(Rotation,np.array([ 1,0]))
    ell_c = add_ellipse(c, (1)*np.sqrt(1/2)*l, (1)*np.sqrt(1/2)*l)
    ell_l = add_ellipse(c+shift_l*l, (1+margin)*np.sqrt(1/2)*l, (1+margin)*np.sqrt(1/2)*l)
    ell_r = add_ellipse(c+shift_r*l, (1+margin)*np.sqrt(1/2)*l, (1+margin)*np.sqrt(1/2)*l)
    tool = subtract(ell_c, [ell_l,ell_r])
    domain = subtract(domain, tool)

def hole_convex(domain, c, l, theta, margin = 0.05):
    co, so = np.cos(theta), np.sin(theta)
    Rotation = np.array(((co, -so), (so, co)))
    shift_l = np.matmul(Rotation,np.array([-1,0]))
    shift_r = np.matmul(Rotation,np.array([ 1,0]))
    ell_c = add_ellipse(c, (1-margin)*np.sqrt(1/2)*l, (1-margin)*np.sqrt(1/2)*l)
    domain = subtract(domain, ell_c)

# %%
# arrange the tools
n_holes_x = 5
n_holes_y = 3
min_n_holes = np.min((n_holes_x,n_holes_y))
scale = 1-4*0.2/min_n_holes
l = scale/min_n_holes

xx = scale*(np.arange(n_holes_x)-n_holes_x/2+0.5)/min_n_holes+0.5
yy = scale*(np.arange(n_holes_y)-n_holes_y/2+0.5)/min_n_holes+0.5
cx,cy = np.meshgrid(xx,yy)
cx = cx.reshape(n_holes_x*n_holes_y)
cy = cy.reshape(n_holes_x*n_holes_y)
c = np.vstack((cx,cy)) # hole coordinate

s_xx = (-1)**np.arange(n_holes_x)
s_yy = (-1)**np.arange(n_holes_y)
sgn_x,sgn_y = np.meshgrid(s_xx,s_yy)
sgn = sgn_x*sgn_y
sgn = sgn.reshape(n_holes_x*n_holes_y)
theta = np.pi*(1-sgn)/4 # hole orientation

xx_l = scale*(-1-n_holes_x/2+0.5)/min_n_holes+0.5
xx_r = scale*(len(xx)-n_holes_x/2+0.5)/min_n_holes+0.5
cx_l,cy_l = np.meshgrid(xx_l,yy)
cx_r,cy_r = np.meshgrid(xx_r,yy)
c_l = np.vstack((cx_l.T,cy_l.T)) # hole coordinate (left edge)
c_r = np.vstack((cx_r.T,cy_r.T)) # hole coordinate (right edge)

s_xx_l = (-1)**(-1)
s_xx_r = (-1)**(len(xx))
sgn_l = s_xx_l*s_yy
sgn_r = s_xx_r*s_yy

# %%
# add a slight rotation
center = np.array([0.5,0.5])
tilt = np.pi/25
c_t = np.cos(tilt)
s_t = np.sin(tilt)
rotation = [[c_t,s_t],[-s_t,c_t]]
c = ((rotation@(c.T-center).T).T  + center).T # hole coordinate
c_l = ((rotation@(c_l.T-center).T).T + center).T # hole coordinate (left edge)
c_r = ((rotation@(c_r.T-center).T).T + center).T # hole coordinate (right edge)

theta = theta - tilt # hole orientation

# %%
reset_geometry()

Lx = 1
Ly = 1

meshsize_min = 0.015
meshsize_max = 0.015

pygmsh_mesh_functions.hmeshmin = meshsize_min
pygmsh_mesh_functions.hmeshmax = meshsize_max

domain = add_polygon([(0, 0), (Lx, 0), (Lx, Ly), (0, Ly)])
X0 = np.array([0, 0])

#OPERATIONS ON DOMAIN
for i in range(len(theta)):
#     hole_NPR(domain, c[:,i], l, theta[i], margin = 0.2)
    hole_NPR_rounded(domain, c[:,i], l, theta[i], margin = 0.2)

# for i in range(len(yy)):
#     if sgn_l[i] == 1:
#         hole_concave(domain, c_l[:,i], l, -tilt, margin = 0.2)
#     else:
#         hole_convex(domain, c_l[:,i], l, -tilt, margin = 0.2)
#     if sgn_r[i] == 1:
#         hole_concave(domain, c_r[:,i], l, -tilt, margin = 0.2)
#     else:
#         hole_convex(domain, c_r[:,i], l, -tilt, margin = 0.2)


#CREATE AND STORE MESH
sample_name = "test_NPR_3_tilt_rounded.xdmf"
out_dir = pathlib.Path("output_files")
out_dir.mkdir(parents=True, exist_ok=True)
mesh = create_fenics_mesh(mesh_path = out_dir / sample_name, verbose=True)
cell_type = mesh.cell_name()
with create_XDMFFile(out_dir / sample_name) as xf:
    xf.write(mesh)
    
plot(mesh)
len(mesh.coordinates())
# Out:
# Info    : Running '/home/fenics/.local/bin/gmsh -3 /tmp/tmpr9fg1q60.geo -format msh -bin -o /tmp/tmp6u9yf35a.msh' [Gmsh 4.9.5, 1 node, max. 1 thread]
# Info    : Started on Sat Apr 30 15:12:36 2022
# Info    : Reading '/tmp/tmpr9fg1q60.geo'...
# Info    : Cannot bind existing OpenCASCADE surface 7 to second tag 8
# Info    : Could not preserve tag of 2D object 8 (->7)
# Info    : Cannot bind existing OpenCASCADE surface 7 to second tag 9
# Info    : Could not preserve tag of 2D object 9 (->7)
# Info    : Cannot bind existing OpenCASCADE surface 22 to second tag 23
# Info    : Could not preserve tag of 2D object 23 (->22)
# Info    : Cannot bind existing OpenCASCADE surface 22 to second tag 24
# Info    : Could not preserve tag of 2D object 24 (->22)
# Info    : Cannot bind existing OpenCASCADE surface 51 to second tag 52
# Info    : Could not preserve tag of 2D object 52 (->51)
# Info    : Cannot bind existing OpenCASCADE surface 51 to second tag 53
# Info    : Could not preserve tag of 2D object 53 (->51)
# Info    : Cannot bind existing OpenCASCADE surface 95 to second tag 96
# Info    : Could not preserve tag of 2D object 96 (->95)
# Info    : Cannot bind existing OpenCASCADE surface 95 to second tag 97
# Info    : Could not preserve tag of 2D object 97 (->95)
# Info    : Cannot bind existing OpenCASCADE surface 152 to second tag 153
# Info    : Could not preserve tag of 2D object 153 (->152)
# Info    : Cannot bind existing OpenCASCADE surface 152 to second tag 154
# Info    : Could not preserve tag of 2D object 154 (->152)
# Info    : Cannot bind existing OpenCASCADE surface 226 to second tag 227
# Info    : Could not preserve tag of 2D object 227 (->226)
# Info    : Cannot bind existing OpenCASCADE surface 226 to second tag 228
# Info    : Could not preserve tag of 2D object 228 (->226)
# Info    : Cannot bind existing OpenCASCADE surface 307 to second tag 308
# Info    : Could not preserve tag of 2D object 308 (->307)
# Info    : Cannot bind existing OpenCASCADE surface 307 to second tag 309
# Info    : Could not preserve tag of 2D object 309 (->307)
# Info    : Cannot bind existing OpenCASCADE surface 401 to second tag 402
# Info    : Could not preserve tag of 2D object 402 (->401)
# Info    : Cannot bind existing OpenCASCADE surface 401 to second tag 403
# Info    : Could not preserve tag of 2D object 403 (->401)
# Info    : Cannot bind existing OpenCASCADE surface 508 to second tag 509
# Info    : Could not preserve tag of 2D object 509 (->508)
# Info    : Cannot bind existing OpenCASCADE surface 508 to second tag 510
# Info    : Could not preserve tag of 2D object 510 (->508)
# Info    : Cannot bind existing OpenCASCADE surface 630 to second tag 631
# Info    : Could not preserve tag of 2D object 631 (->630)
# Info    : Cannot bind existing OpenCASCADE surface 630 to second tag 632
# Info    : Could not preserve tag of 2D object 632 (->630)
# Info    : Cannot bind existing OpenCASCADE surface 768 to second tag 769
# Info    : Could not preserve tag of 2D object 769 (->768)
# Info    : Cannot bind existing OpenCASCADE surface 768 to second tag 770
# Info    : Could not preserve tag of 2D object 770 (->768)
# Info    : Cannot bind existing OpenCASCADE surface 916 to second tag 917
# Info    : Could not preserve tag of 2D object 917 (->916)
# Info    : Cannot bind existing OpenCASCADE surface 916 to second tag 918
# Info    : Could not preserve tag of 2D object 918 (->916)
# Info    : Cannot bind existing OpenCASCADE surface 1073 to second tag 1074
# Info    : Could not preserve tag of 2D object 1074 (->1073)
# Info    : Cannot bind existing OpenCASCADE surface 1073 to second tag 1075
# Info    : Could not preserve tag of 2D object 1075 (->1073)
# Info    : Cannot bind existing OpenCASCADE surface 1245 to second tag 1246
# Info    : Could not preserve tag of 2D object 1246 (->1245)
# Info    : Cannot bind existing OpenCASCADE surface 1245 to second tag 1247
# Info    : Could not preserve tag of 2D object 1247 (->1245)
# Info    : Cannot bind existing OpenCASCADE surface 1430 to second tag 1431
# Info    : Could not preserve tag of 2D object 1431 (->1430)
# Info    : Cannot bind existing OpenCASCADE surface 1430 to second tag 1432
# Info    : Could not preserve tag of 2D object 1432 (->1430)
# Info    : Done reading '/tmp/tmpr9fg1q60.geo'
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1438 (Ellipse)
# Info    : [ 10%] Meshing curve 1439 (Ellipse)
# Info    : [ 10%] Meshing curve 1442 (Ellipse)
# Info    : [ 10%] Meshing curve 1443 (Ellipse)
# Info    : [ 10%] Meshing curve 1444 (Ellipse)
# Info    : [ 10%] Meshing curve 1445 (Ellipse)
# Info    : [ 10%] Meshing curve 1446 (Ellipse)
# Info    : [ 10%] Meshing curve 1447 (Ellipse)
# Info    : [ 10%] Meshing curve 1448 (Ellipse)
# Info    : [ 10%] Meshing curve 1449 (Line)
# Info    : [ 10%] Meshing curve 1450 (Ellipse)
# Info    : [ 10%] Meshing curve 1451 (Ellipse)
# Info    : [ 10%] Meshing curve 1452 (Ellipse)
# Info    : [ 10%] Meshing curve 1453 (Ellipse)
# Info    : [ 10%] Meshing curve 1454 (Ellipse)
# Info    : [ 10%] Meshing curve 1455 (Line)
# Info    : [ 10%] Meshing curve 1456 (Ellipse)
# Info    : [ 10%] Meshing curve 1457 (Ellipse)
# Info    : [ 10%] Meshing curve 1458 (Ellipse)
# Info    : [ 10%] Meshing curve 1459 (Ellipse)
# Info    : [ 20%] Meshing curve 1460 (Ellipse)
# Info    : [ 20%] Meshing curve 1461 (Ellipse)
# Info    : [ 20%] Meshing curve 1462 (Ellipse)
# Info    : [ 20%] Meshing curve 1463 (Ellipse)
# Info    : [ 20%] Meshing curve 1464 (Line)
# Info    : [ 20%] Meshing curve 1465 (Ellipse)
# Info    : [ 20%] Meshing curve 1466 (Ellipse)
# Info    : [ 20%] Meshing curve 1467 (Ellipse)
# Info    : [ 20%] Meshing curve 1468 (Ellipse)
# Info    : [ 20%] Meshing curve 1469 (Ellipse)
# Info    : [ 20%] Meshing curve 1470 (Ellipse)
# Info    : [ 20%] Meshing curve 1471 (Ellipse)
# Info    : [ 20%] Meshing curve 1472 (Ellipse)
# Info    : [ 20%] Meshing curve 1473 (Ellipse)
# Info    : [ 20%] Meshing curve 1474 (Ellipse)
# Info    : [ 20%] Meshing curve 1475 (Ellipse)
# Info    : [ 20%] Meshing curve 1476 (Ellipse)
# Info    : [ 20%] Meshing curve 1477 (Ellipse)
# Info    : [ 20%] Meshing curve 1478 (Line)
# Info    : [ 20%] Meshing curve 1479 (Line)
# Info    : [ 30%] Meshing curve 1480 (Line)
# Info    : [ 30%] Meshing curve 1481 (Ellipse)
# Info    : [ 30%] Meshing curve 1482 (Ellipse)
# Info    : [ 30%] Meshing curve 1483 (Line)
# Info    : [ 30%] Meshing curve 1484 (Ellipse)
# Info    : [ 30%] Meshing curve 1485 (Ellipse)
# Info    : [ 30%] Meshing curve 1486 (Line)
# Info    : [ 30%] Meshing curve 1487 (Ellipse)
# Info    : [ 30%] Meshing curve 1488 (Ellipse)
# Info    : [ 30%] Meshing curve 1489 (Ellipse)
# Info    : [ 30%] Meshing curve 1490 (Ellipse)
# Info    : [ 30%] Meshing curve 1491 (Ellipse)
# Info    : [ 30%] Meshing curve 1492 (Ellipse)
# Info    : [ 30%] Meshing curve 1493 (Ellipse)
# Info    : [ 30%] Meshing curve 1494 (Line)
# Info    : [ 30%] Meshing curve 1495 (Ellipse)
# Info    : [ 30%] Meshing curve 1496 (Ellipse)
# Info    : [ 30%] Meshing curve 1497 (Ellipse)
# Info    : [ 30%] Meshing curve 1498 (Ellipse)
# Info    : [ 40%] Meshing curve 1499 (Ellipse)
# Info    : [ 40%] Meshing curve 1500 (Ellipse)
# Info    : [ 40%] Meshing curve 1501 (Ellipse)
# Info    : [ 40%] Meshing curve 1502 (Ellipse)
# Info    : [ 40%] Meshing curve 1503 (Ellipse)
# Info    : [ 40%] Meshing curve 1504 (Ellipse)
# Info    : [ 40%] Meshing curve 1505 (Ellipse)
# Info    : [ 40%] Meshing curve 1506 (Ellipse)
# Info    : [ 40%] Meshing curve 1507 (Line)
# Info    : [ 40%] Meshing curve 1508 (Line)
# Info    : [ 40%] Meshing curve 1509 (Line)
# Info    : [ 40%] Meshing curve 1510 (Ellipse)
# Info    : [ 40%] Meshing curve 1511 (Ellipse)
# Info    : [ 40%] Meshing curve 1512 (Ellipse)
# Info    : [ 40%] Meshing curve 1513 (Ellipse)
# Info    : [ 40%] Meshing curve 1514 (Ellipse)
# Info    : [ 40%] Meshing curve 1515 (Ellipse)
# Info    : [ 40%] Meshing curve 1516 (Ellipse)
# Info    : [ 40%] Meshing curve 1517 (Ellipse)
# Info    : [ 40%] Meshing curve 1518 (Ellipse)
# Info    : [ 50%] Meshing curve 1519 (Ellipse)
# Info    : [ 50%] Meshing curve 1520 (Ellipse)
# Info    : [ 50%] Meshing curve 1521 (Ellipse)
# Info    : [ 50%] Meshing curve 1522 (Ellipse)
# Info    : [ 50%] Meshing curve 1523 (Ellipse)
# Info    : [ 50%] Meshing curve 1524 (Ellipse)
# Info    : [ 50%] Meshing curve 1525 (Ellipse)
# Info    : [ 50%] Meshing curve 1526 (Ellipse)
# Info    : [ 50%] Meshing curve 1527 (Ellipse)
# Info    : [ 50%] Meshing curve 1528 (Ellipse)
# Info    : [ 50%] Meshing curve 1529 (Ellipse)
# Info    : [ 50%] Meshing curve 1530 (Ellipse)
# Info    : [ 50%] Meshing curve 1531 (Ellipse)
# Info    : [ 50%] Meshing curve 1532 (Ellipse)
# Info    : [ 50%] Meshing curve 1533 (Ellipse)
# Info    : [ 50%] Meshing curve 1534 (Ellipse)
# Info    : [ 50%] Meshing curve 1535 (Ellipse)
# Info    : [ 50%] Meshing curve 1536 (Ellipse)
# Info    : [ 50%] Meshing curve 1537 (Ellipse)
# Info    : [ 60%] Meshing curve 1538 (Ellipse)
# Info    : [ 60%] Meshing curve 1539 (Ellipse)
# Info    : [ 60%] Meshing curve 1540 (Ellipse)
# Info    : [ 60%] Meshing curve 1541 (Ellipse)
# Info    : [ 60%] Meshing curve 1542 (Ellipse)
# Info    : [ 60%] Meshing curve 1543 (Ellipse)
# Info    : [ 60%] Meshing curve 1544 (Ellipse)
# Info    : [ 60%] Meshing curve 1545 (Ellipse)
# Info    : [ 60%] Meshing curve 1546 (Ellipse)
# Info    : [ 60%] Meshing curve 1547 (Ellipse)
# Info    : [ 60%] Meshing curve 1548 (Ellipse)
# Info    : [ 60%] Meshing curve 1549 (Ellipse)
# Info    : [ 60%] Meshing curve 1550 (Ellipse)
# Info    : [ 60%] Meshing curve 1551 (Ellipse)
# Info    : [ 60%] Meshing curve 1552 (Ellipse)
# Info    : [ 60%] Meshing curve 1553 (Ellipse)
# Info    : [ 60%] Meshing curve 1554 (Ellipse)
# Info    : [ 60%] Meshing curve 1555 (Ellipse)
# Info    : [ 60%] Meshing curve 1556 (Ellipse)
# Info    : [ 60%] Meshing curve 1557 (Ellipse)
# Info    : [ 70%] Meshing curve 1558 (Ellipse)
# Info    : [ 70%] Meshing curve 1559 (Ellipse)
# Info    : [ 70%] Meshing curve 1560 (Ellipse)
# Info    : [ 70%] Meshing curve 1561 (Ellipse)
# Info    : [ 70%] Meshing curve 1562 (Ellipse)
# Info    : [ 70%] Meshing curve 1563 (Ellipse)
# Info    : [ 70%] Meshing curve 1564 (Ellipse)
# Info    : [ 70%] Meshing curve 1565 (Ellipse)
# Info    : [ 70%] Meshing curve 1566 (Ellipse)
# Info    : [ 70%] Meshing curve 1567 (Ellipse)
# Info    : [ 70%] Meshing curve 1568 (Ellipse)
# Info    : [ 70%] Meshing curve 1569 (Ellipse)
# Info    : [ 70%] Meshing curve 1570 (Ellipse)
# Info    : [ 70%] Meshing curve 1571 (Ellipse)
# Info    : [ 70%] Meshing curve 1572 (Ellipse)
# Info    : [ 70%] Meshing curve 1573 (Ellipse)
# Info    : [ 70%] Meshing curve 1574 (Ellipse)
# Info    : [ 70%] Meshing curve 1575 (Ellipse)
# Info    : [ 70%] Meshing curve 1576 (Ellipse)
# Info    : [ 80%] Meshing curve 1577 (Ellipse)
# Info    : [ 80%] Meshing curve 1578 (Ellipse)
# Info    : [ 80%] Meshing curve 1579 (Ellipse)
# Info    : [ 80%] Meshing curve 1580 (Ellipse)
# Info    : [ 80%] Meshing curve 1581 (Ellipse)
# Info    : [ 80%] Meshing curve 1582 (Ellipse)
# Info    : [ 80%] Meshing curve 1583 (Ellipse)
# Info    : [ 80%] Meshing curve 1584 (Ellipse)
# Info    : [ 80%] Meshing curve 1585 (Ellipse)
# Info    : [ 80%] Meshing curve 1586 (Ellipse)
# Info    : [ 80%] Meshing curve 1587 (Ellipse)
# Info    : [ 80%] Meshing curve 1588 (Ellipse)
# Info    : [ 80%] Meshing curve 1589 (Ellipse)
# Info    : [ 80%] Meshing curve 1590 (Ellipse)
# Info    : [ 80%] Meshing curve 1591 (Ellipse)
# Info    : [ 80%] Meshing curve 1592 (Ellipse)
# Info    : [ 80%] Meshing curve 1593 (Ellipse)
# Info    : [ 80%] Meshing curve 1594 (Ellipse)
# Info    : [ 80%] Meshing curve 1595 (Ellipse)
# Info    : [ 80%] Meshing curve 1596 (Ellipse)
# Info    : [ 90%] Meshing curve 1597 (Ellipse)
# Info    : [ 90%] Meshing curve 1598 (Ellipse)
# Info    : [ 90%] Meshing curve 1599 (Ellipse)
# Info    : [ 90%] Meshing curve 1600 (Ellipse)
# Info    : [ 90%] Meshing curve 1601 (Ellipse)
# Info    : [ 90%] Meshing curve 1602 (Ellipse)
# Info    : [ 90%] Meshing curve 1603 (Ellipse)
# Info    : [ 90%] Meshing curve 1604 (Ellipse)
# Info    : [ 90%] Meshing curve 1605 (Ellipse)
# Info    : [ 90%] Meshing curve 1606 (Ellipse)
# Info    : [ 90%] Meshing curve 1607 (Ellipse)
# Info    : [ 90%] Meshing curve 1608 (Ellipse)
# Info    : [ 90%] Meshing curve 1609 (Ellipse)
# Info    : [ 90%] Meshing curve 1610 (Ellipse)
# Info    : [ 90%] Meshing curve 1611 (Ellipse)
# Info    : [ 90%] Meshing curve 1612 (Ellipse)
# Info    : [ 90%] Meshing curve 1613 (Ellipse)
# Info    : [ 90%] Meshing curve 1614 (Ellipse)
# Info    : [ 90%] Meshing curve 1615 (Ellipse)
# Info    : [100%] Meshing curve 1616 (Ellipse)
# Info    : [100%] Meshing curve 1617 (Ellipse)
# Info    : [100%] Meshing curve 1618 (Ellipse)
# Info    : [100%] Meshing curve 1619 (Ellipse)
# Info    : [100%] Meshing curve 1620 (Ellipse)
# Info    : [100%] Meshing curve 1621 (Ellipse)
# Info    : [100%] Meshing curve 1622 (Ellipse)
# Info    : [100%] Meshing curve 1623 (Ellipse)
# Info    : [100%] Meshing curve 1624 (Ellipse)
# Info    : [100%] Meshing curve 1625 (Ellipse)
# Info    : [100%] Meshing curve 1626 (Ellipse)
# Info    : [100%] Meshing curve 1627 (Ellipse)
# Info    : [100%] Meshing curve 1628 (Ellipse)
# Info    : [100%] Meshing curve 1629 (Ellipse)
# Info    : [100%] Meshing curve 1630 (Ellipse)
# Info    : [100%] Meshing curve 1631 (Ellipse)
# Info    : [100%] Meshing curve 1632 (Ellipse)
# Info    : [100%] Meshing curve 1633 (Ellipse)
# Info    : [100%] Meshing curve 1634 (Ellipse)
# Info    : Done meshing 1D (Wall 0.024485s, CPU 0.02439s)
# Info    : Meshing 2D...
# Info    : Meshing surface 6 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.178947s, CPU 0.178944s)
# Info    : Meshing 3D...
# Info    : Done meshing 3D (Wall 2.85e-05s, CPU 2.9e-05s)
# Info    : 5096 nodes 10403 elements
# Info    : Writing '/tmp/tmp6u9yf35a.msh'...
# Info    : Done writing '/tmp/tmp6u9yf35a.msh'
# Info    : Stopped on Sat Apr 30 15:12:38 2022 (From start: Wall 1.42868s, CPU 1.61249s)
# 5096
