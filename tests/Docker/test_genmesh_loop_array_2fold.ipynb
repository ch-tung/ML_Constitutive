# %%
from fenics import *
from dolfin_adjoint import *
import pygmsh_mesh_functions
from pygmsh_mesh_functions import *
import meshio
import numpy as np
import matplotlib.pyplot as plt

import skimage.io
from skimage.measure import find_contours, subdivide_polygon, approximate_polygon

# %%
def hole_polygon(domain, polygon):
    tool = add_polygon(polygon)
    domain = subtract(domain, tool)

# %%
def arrange_array(n_holes_x, n_holes_y, d_x, d_y,
                  freq = 1, phase = 0, shift = np.array([0,0]), twist = 0):
    
    min_n_holes = np.min((n_holes_x,n_holes_y))

#     xx = scale*(np.arange(n_holes_x)-n_holes_x/2+0.5)/size+0.5
#     yy = scale*(np.arange(n_holes_y)-n_holes_y/2+0.5)/size+0.5
    xx = (np.arange(n_holes_x)-n_holes_x/2+0.5)*d_x+0.5
    yy = (np.arange(n_holes_y)-n_holes_y/2+0.5)*d_y+0.5
    cx,cy = np.meshgrid(xx,yy)
    
    cx = cx.reshape(n_holes_x*n_holes_y)
    cy = cy.reshape(n_holes_x*n_holes_y)
    c = np.vstack((cx,cy)) # hole coordinate

    s_xx = (-1)**np.arange(n_holes_x)
    s_yy = (-1)**np.arange(n_holes_y)
    sgn_x,sgn_y = np.meshgrid(s_xx,s_yy)
    sgn = sgn_x*sgn_y
    sgn = sgn.reshape(n_holes_x*n_holes_y)
    theta = np.pi*(sgn/2)*freq + phase # hole orientation
    theta = theta + (np.random.rand(len(theta))-0.5)*twist
    
    return(c, theta)

# %% [markdown]
# ## Generate holes

# %% [markdown]
# ### define parameters

# %%
A = np.array([1.0,0.75,0.01])
margin = 0.2

# %% [markdown]
# ### preview tools

# %%
# arrange the tools
size = 4
c, theta = arrange_array(5, 3, 1/size, 1/size, freq = 1/2, phase = np.pi/4)

# define tools
n_phi = 60
phi = np.arange(n_phi+1)/n_phi*2*np.pi
scale = 1/size/2*(1-margin)

r = np.zeros((2,n_phi+1))
for i in range(len(A)):
    ri = np.array([np.cos(phi), np.sin(phi)])*np.cos(2*(i)*phi)*A[i]
    r = r+ri
# r = r/np.sum(A)
r = r*scale

# plot arranged tools
fig, ax = plt.subplots(1, 1, figsize=(6, 6))
for i in range(len(theta)):
    co, so = np.cos(theta[i]), np.sin(theta[i])
    Rotation = np.array(((co, -so), (so, co)))
    ri = Rotation@r
    ax.plot(ri[0,:] + c[0,i], ri[1,:] + c[1,i],'-',linewidth=3)
  
ax.plot([0,1,1,0,0],[0,0,1,1,0],'-k')
ax.set_xlim([-0.25,1.25])
ax.set_ylim([-0.25,1.25])
# Out:
# (-0.25, 1.25)

# %% [markdown]
# ## Generate Mesh

# %%
Lx = 1
Ly = 1

meshsize_min = 0.015
meshsize_max = 0.015

pygmsh_mesh_functions.hmeshmin = meshsize_min
pygmsh_mesh_functions.hmeshmax = meshsize_max

reset_geometry()

domain = add_polygon([(0, 0), (Lx, 0), (Lx, Ly), (0, Ly)])
X0 = np.array([0, 0])

#OPERATIONS ON DOMAIN
for i in range(len(theta)):
    co, so = np.cos(theta[i]), np.sin(theta[i])
    Rotation = np.array(((co, -so), (so, co)))
    
    polygon = (Rotation@r).T
    polygon = polygon[:-1]

    polygon_subdivide = subdivide_polygon(polygon, degree=2, preserve_ends=True)
    polygon_approx = approximate_polygon(polygon_subdivide,0.0025)
    polygon_shift = polygon_approx + c[:,i]

    hole_polygon(domain, polygon_shift)

#CREATE AND STORE MESH
sample_name = "test_loop_array_2fold_{}_{}_{}.xdmf".format(A[0],A[1],A[2])
out_dir = pathlib.Path("output_files")
out_dir.mkdir(parents=True, exist_ok=True)
mesh = create_fenics_mesh(mesh_path = out_dir / sample_name, verbose=True)
cell_type = mesh.cell_name()
with create_XDMFFile(out_dir / sample_name) as xf:
    xf.write(mesh)
    
plot(mesh)
len(mesh.coordinates())
# Out:
# Info    : Running '/home/fenics/.local/bin/gmsh -3 /tmp/tmptyxuj0ba.geo -format msh -bin -o /tmp/tmphzmxyhg4.msh' [Gmsh 4.9.5, 1 node, max. 1 thread]
# Info    : Started on Wed May 18 17:17:27 2022
# Info    : Reading '/tmp/tmptyxuj0ba.geo'...
# Info    : Done reading '/tmp/tmptyxuj0ba.geo'
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 2705 (Line)
# Info    : [ 10%] Meshing curve 2706 (Line)
# Info    : [ 10%] Meshing curve 2707 (Line)
# Info    : [ 10%] Meshing curve 2708 (Line)
# Info    : [ 10%] Meshing curve 2709 (Line)
# Info    : [ 10%] Meshing curve 2710 (Line)
# Info    : [ 10%] Meshing curve 2711 (Line)
# Info    : [ 10%] Meshing curve 2712 (Line)
# Info    : [ 10%] Meshing curve 2713 (Line)
# Info    : [ 10%] Meshing curve 2714 (Line)
# Info    : [ 10%] Meshing curve 2715 (Line)
# Info    : [ 10%] Meshing curve 2716 (Line)
# Info    : [ 10%] Meshing curve 2717 (Line)
# Info    : [ 10%] Meshing curve 2718 (Line)
# Info    : [ 10%] Meshing curve 2719 (Line)
# Info    : [ 10%] Meshing curve 2720 (Line)
# Info    : [ 10%] Meshing curve 2721 (Line)
# Info    : [ 10%] Meshing curve 2722 (Line)
# Info    : [ 10%] Meshing curve 2723 (Line)
# Info    : [ 10%] Meshing curve 2724 (Line)
# Info    : [ 10%] Meshing curve 2725 (Line)
# Info    : [ 10%] Meshing curve 2726 (Line)
# Info    : [ 10%] Meshing curve 2727 (Line)
# Info    : [ 10%] Meshing curve 2728 (Line)
# Info    : [ 10%] Meshing curve 2729 (Line)
# Info    : [ 10%] Meshing curve 2730 (Line)
# Info    : [ 10%] Meshing curve 2731 (Line)
# Info    : [ 10%] Meshing curve 2732 (Line)
# Info    : [ 10%] Meshing curve 2733 (Line)
# Info    : [ 10%] Meshing curve 2734 (Line)
# Info    : [ 10%] Meshing curve 2735 (Line)
# Info    : [ 10%] Meshing curve 2736 (Line)
# Info    : [ 10%] Meshing curve 2737 (Line)
# Info    : [ 10%] Meshing curve 2738 (Line)
# Info    : [ 10%] Meshing curve 2739 (Line)
# Info    : [ 10%] Meshing curve 2740 (Line)
# Info    : [ 10%] Meshing curve 2741 (Line)
# Info    : [ 10%] Meshing curve 2742 (Line)
# Info    : [ 20%] Meshing curve 2743 (Line)
# Info    : [ 20%] Meshing curve 2744 (Line)
# Info    : [ 20%] Meshing curve 2745 (Line)
# Info    : [ 20%] Meshing curve 2746 (Line)
# Info    : [ 20%] Meshing curve 2747 (Line)
# Info    : [ 20%] Meshing curve 2748 (Line)
# Info    : [ 20%] Meshing curve 2749 (Line)
# Info    : [ 20%] Meshing curve 2750 (Line)
# Info    : [ 20%] Meshing curve 2751 (Line)
# Info    : [ 20%] Meshing curve 2752 (Line)
# Info    : [ 20%] Meshing curve 2753 (Line)
# Info    : [ 20%] Meshing curve 2754 (Line)
# Info    : [ 20%] Meshing curve 2755 (Line)
# Info    : [ 20%] Meshing curve 2756 (Line)
# Info    : [ 20%] Meshing curve 2757 (Line)
# Info    : [ 20%] Meshing curve 2758 (Line)
# Info    : [ 20%] Meshing curve 2759 (Line)
# Info    : [ 20%] Meshing curve 2760 (Line)
# Info    : [ 20%] Meshing curve 2761 (Line)
# Info    : [ 20%] Meshing curve 2762 (Line)
# Info    : [ 20%] Meshing curve 2763 (Line)
# Info    : [ 20%] Meshing curve 2764 (Line)
# Info    : [ 20%] Meshing curve 2765 (Line)
# Info    : [ 20%] Meshing curve 2766 (Line)
# Info    : [ 20%] Meshing curve 2767 (Line)
# Info    : [ 20%] Meshing curve 2768 (Line)
# Info    : [ 20%] Meshing curve 2769 (Line)
# Info    : [ 20%] Meshing curve 2770 (Line)
# Info    : [ 20%] Meshing curve 2771 (Line)
# Info    : [ 20%] Meshing curve 2772 (Line)
# Info    : [ 20%] Meshing curve 2773 (Line)
# Info    : [ 20%] Meshing curve 2774 (Line)
# Info    : [ 20%] Meshing curve 2775 (Line)
# Info    : [ 20%] Meshing curve 2776 (Line)
# Info    : [ 20%] Meshing curve 2777 (Line)
# Info    : [ 20%] Meshing curve 2778 (Line)
# Info    : [ 20%] Meshing curve 2779 (Line)
# Info    : [ 30%] Meshing curve 2780 (Line)
# Info    : [ 30%] Meshing curve 2781 (Line)
# Info    : [ 30%] Meshing curve 2782 (Line)
# Info    : [ 30%] Meshing curve 2783 (Line)
# Info    : [ 30%] Meshing curve 2784 (Line)
# Info    : [ 30%] Meshing curve 2785 (Line)
# Info    : [ 30%] Meshing curve 2786 (Line)
# Info    : [ 30%] Meshing curve 2787 (Line)
# Info    : [ 30%] Meshing curve 2788 (Line)
# Info    : [ 30%] Meshing curve 2789 (Line)
# Info    : [ 30%] Meshing curve 2790 (Line)
# Info    : [ 30%] Meshing curve 2791 (Line)
# Info    : [ 30%] Meshing curve 2792 (Line)
# Info    : [ 30%] Meshing curve 2793 (Line)
# Info    : [ 30%] Meshing curve 2794 (Line)
# Info    : [ 30%] Meshing curve 2795 (Line)
# Info    : [ 30%] Meshing curve 2796 (Line)
# Info    : [ 30%] Meshing curve 2797 (Line)
# Info    : [ 30%] Meshing curve 2798 (Line)
# Info    : [ 30%] Meshing curve 2799 (Line)
# Info    : [ 30%] Meshing curve 2800 (Line)
# Info    : [ 30%] Meshing curve 2801 (Line)
# Info    : [ 30%] Meshing curve 2802 (Line)
# Info    : [ 30%] Meshing curve 2803 (Line)
# Info    : [ 30%] Meshing curve 2804 (Line)
# Info    : [ 30%] Meshing curve 2805 (Line)
# Info    : [ 30%] Meshing curve 2806 (Line)
# Info    : [ 30%] Meshing curve 2807 (Line)
# Info    : [ 30%] Meshing curve 2808 (Line)
# Info    : [ 30%] Meshing curve 2809 (Line)
# Info    : [ 30%] Meshing curve 2810 (Line)
# Info    : [ 30%] Meshing curve 2811 (Line)
# Info    : [ 30%] Meshing curve 2812 (Line)
# Info    : [ 30%] Meshing curve 2813 (Line)
# Info    : [ 30%] Meshing curve 2814 (Line)
# Info    : [ 30%] Meshing curve 2815 (Line)
# Info    : [ 30%] Meshing curve 2816 (Line)
# Info    : [ 30%] Meshing curve 2817 (Line)
# Info    : [ 40%] Meshing curve 2818 (Line)
# Info    : [ 40%] Meshing curve 2819 (Line)
# Info    : [ 40%] Meshing curve 2820 (Line)
# Info    : [ 40%] Meshing curve 2821 (Line)
# Info    : [ 40%] Meshing curve 2822 (Line)
# Info    : [ 40%] Meshing curve 2823 (Line)
# Info    : [ 40%] Meshing curve 2824 (Line)
# Info    : [ 40%] Meshing curve 2825 (Line)
# Info    : [ 40%] Meshing curve 2826 (Line)
# Info    : [ 40%] Meshing curve 2827 (Line)
# Info    : [ 40%] Meshing curve 2828 (Line)
# Info    : [ 40%] Meshing curve 2829 (Line)
# Info    : [ 40%] Meshing curve 2830 (Line)
# Info    : [ 40%] Meshing curve 2831 (Line)
# Info    : [ 40%] Meshing curve 2832 (Line)
# Info    : [ 40%] Meshing curve 2833 (Line)
# Info    : [ 40%] Meshing curve 2834 (Line)
# Info    : [ 40%] Meshing curve 2835 (Line)
# Info    : [ 40%] Meshing curve 2836 (Line)
# Info    : [ 40%] Meshing curve 2837 (Line)
# Info    : [ 40%] Meshing curve 2838 (Line)
# Info    : [ 40%] Meshing curve 2839 (Line)
# Info    : [ 40%] Meshing curve 2840 (Line)
# Info    : [ 40%] Meshing curve 2841 (Line)
# Info    : [ 40%] Meshing curve 2842 (Line)
# Info    : [ 40%] Meshing curve 2843 (Line)
# Info    : [ 40%] Meshing curve 2844 (Line)
# Info    : [ 40%] Meshing curve 2845 (Line)
# Info    : [ 40%] Meshing curve 2846 (Line)
# Info    : [ 40%] Meshing curve 2847 (Line)
# Info    : [ 40%] Meshing curve 2848 (Line)
# Info    : [ 40%] Meshing curve 2849 (Line)
# Info    : [ 40%] Meshing curve 2850 (Line)
# Info    : [ 40%] Meshing curve 2851 (Line)
# Info    : [ 40%] Meshing curve 2852 (Line)
# Info    : [ 40%] Meshing curve 2853 (Line)
# Info    : [ 40%] Meshing curve 2854 (Line)
# Info    : [ 50%] Meshing curve 2855 (Line)
# Info    : [ 80%] Meshing curve 2971 (Line)
# Info    : [ 80%] Meshing curve 2972 (Line)
# Info    : [ 80%] Meshing curve 2973 (Line)
# Info    : [ 80%] Meshing curve 2974 (Line)
# Info    : [ 80%] Meshing curve 2975 (Line)
# Info    : [ 80%] Meshing curve 2976 (Line)
# Info    : [ 80%] Meshing curve 2977 (Line)
# Info    : [ 80%] Meshing curve 2978 (Line)
# Info    : [ 80%] Meshing curve 2979 (Line)
# Info    : [ 80%] Meshing curve 2980 (Line)
# Info    : [ 80%] Meshing curve 2981 (Line)
# Info    : [ 80%] Meshing curve 2982 (Line)
# Info    : [ 80%] Meshing curve 2983 (Line)
# Info    : [ 80%] Meshing curve 2984 (Line)
# Info    : [ 80%] Meshing curve 2985 (Line)
# Info    : [ 80%] Meshing curve 2986 (Line)
# Info    : [ 80%] Meshing curve 2987 (Line)
# Info    : [ 80%] Meshing curve 2988 (Line)
# Info    : [ 80%] Meshing curve 2989 (Line)
# Info    : [ 80%] Meshing curve 2990 (Line)
# Info    : [ 80%] Meshing curve 2991 (Line)
# Info    : [ 80%] Meshing curve 2992 (Line)
# Info    : [ 80%] Meshing curve 2993 (Line)
# Info    : [ 80%] Meshing curve 2994 (Line)
# Info    : [ 80%] Meshing curve 2995 (Line)
# Info    : [ 80%] Meshing curve 2996 (Line)
# Info    : [ 80%] Meshing curve 2997 (Line)
# Info    : [ 80%] Meshing curve 2998 (Line)
# Info    : [ 80%] Meshing curve 2999 (Line)
# Info    : [ 80%] Meshing curve 3000 (Line)
# Info    : [ 80%] Meshing curve 3001 (Line)
# Info    : [ 80%] Meshing curve 3002 (Line)
# Info    : [ 80%] Meshing curve 3003 (Line)
# Info    : [ 80%] Meshing curve 3004 (Line)
# Info    : [ 90%] Meshing curve 3005 (Line)
# Info    : [ 90%] Meshing curve 3006 (Line)
# Info    : [ 90%] Meshing curve 3007 (Line)
# Info    : [ 90%] Meshing curve 3008 (Line)
# Info    : [ 90%] Meshing curve 3009 (Line)
# Info    : [ 90%] Meshing curve 3010 (Line)
# Info    : [ 90%] Meshing curve 3011 (Line)
# Info    : [ 90%] Meshing curve 3012 (Line)
# Info    : [ 90%] Meshing curve 3013 (Line)
# Info    : [ 90%] Meshing curve 3014 (Line)
# Info    : [ 90%] Meshing curve 3015 (Line)
# Info    : [ 90%] Meshing curve 3016 (Line)
# Info    : [ 90%] Meshing curve 3017 (Line)
# Info    : [ 90%] Meshing curve 3018 (Line)
# Info    : [ 90%] Meshing curve 3019 (Line)
# Info    : [ 90%] Meshing curve 3020 (Line)
# Info    : [ 90%] Meshing curve 3021 (Line)
# Info    : [ 90%] Meshing curve 3022 (Line)
# Info    : [ 90%] Meshing curve 3023 (Line)
# Info    : [ 90%] Meshing curve 3024 (Line)
# Info    : [ 90%] Meshing curve 3025 (Line)
# Info    : [ 90%] Meshing curve 3026 (Line)
# Info    : [ 90%] Meshing curve 3027 (Line)
# Info    : [ 90%] Meshing curve 3028 (Line)
# Info    : [ 90%] Meshing curve 3029 (Line)
# Info    : [ 90%] Meshing curve 3030 (Line)
# Info    : [ 90%] Meshing curve 3031 (Line)
# Info    : [ 90%] Meshing curve 3032 (Line)
# Info    : [ 90%] Meshing curve 3033 (Line)
# Info    : [ 90%] Meshing curve 3034 (Line)
# Info    : [ 90%] Meshing curve 3035 (Line)
# Info    : [ 90%] Meshing curve 3036 (Line)
# Info    : [ 90%] Meshing curve 3037 (Line)
# Info    : [ 90%] Meshing curve 3038 (Line)
# Info    : [ 90%] Meshing curve 3039 (Line)
# Info    : [ 90%] Meshing curve 3040 (Line)
# Info    : [ 90%] Meshing curve 3041 (Line)
# Info    : [100%] Meshing curve 3042 (Line)
# Info    : [100%] Meshing curve 3043 (Line)
# Info    : [100%] Meshing curve 3044 (Line)
# Info    : [100%] Meshing curve 3045 (Line)
# Info    : [100%] Meshing curve 3046 (Line)
# Info    : [100%] Meshing curve 3047 (Line)
# Info    : [100%] Meshing curve 3048 (Line)
# Info    : [100%] Meshing curve 3049 (Line)
# Info    : [100%] Meshing curve 3050 (Line)
# Info    : [100%] Meshing curve 3051 (Line)
# Info    : [100%] Meshing curve 3052 (Line)
# Info    : [100%] Meshing curve 3053 (Line)
# Info    : [100%] Meshing curve 3054 (Line)
# Info    : [100%] Meshing curve 3055 (Line)
# Info    : [100%] Meshing curve 3056 (Line)
# Info    : [100%] Meshing curve 3057 (Line)
# Info    : [100%] Meshing curve 3058 (Line)
# Info    : [100%] Meshing curve 3059 (Line)
# Info    : [100%] Meshing curve 3060 (Line)
# Info    : [100%] Meshing curve 3061 (Line)
# Info    : [100%] Meshing curve 3062 (Line)
# Info    : [100%] Meshing curve 3063 (Line)
# Info    : [100%] Meshing curve 3064 (Line)
# Info    : [100%] Meshing curve 3065 (Line)
# Info    : [100%] Meshing curve 3066 (Line)
# Info    : [100%] Meshing curve 3067 (Line)
# Info    : [100%] Meshing curve 3068 (Line)
# Info    : [100%] Meshing curve 3069 (Line)
# Info    : [100%] Meshing curve 3070 (Line)
# Info    : [100%] Meshing curve 3071 (Line)
# Info    : [100%] Meshing curve 3072 (Line)
# Info    : [100%] Meshing curve 3073 (Line)
# Info    : [100%] Meshing curve 3074 (Line)
# Info    : [100%] Meshing curve 3075 (Line)
# Info    : [100%] Meshing curve 3076 (Line)
# Info    : [100%] Meshing curve 3077 (Line)
# Info    : [100%] Meshing curve 3078 (Line)
# Info    : Done meshing 1D (Wall 0.0275624s, CPU 0.027562s)
# Info    : Meshing 2D...
# Info    : Meshing surface 6 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.158111s, CPU 0.138463s)
# Info    : Meshing 3D...
# Info    : Done meshing 3D (Wall 2.08e-05s, CPU 2e-05s)
# Info    : 4192 nodes 8774 elements
# Info    : Writing '/tmp/tmphzmxyhg4.msh'...
# Info    : Done writing '/tmp/tmphzmxyhg4.msh'
# Info    : Stopped on Wed May 18 17:17:27 2022 (From start: Wall 0.521156s, CPU 0.682446s)
# 4192
