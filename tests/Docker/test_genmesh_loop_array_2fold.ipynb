# %%
from fenics import *
from dolfin_adjoint import *
import pygmsh_mesh_functions
from pygmsh_mesh_functions import *
import meshio
import numpy as np
import matplotlib.pyplot as plt

import skimage.io
from skimage.measure import find_contours, subdivide_polygon, approximate_polygon

# %%
def hole_polygon(domain, polygon):
    tool = add_polygon(polygon)
    domain = subtract(domain, tool)

# %%
def arrange_array(n_holes_x, n_holes_y, d_x, d_y,
                  freq = 1, phase = 0, shift = np.array([0,0]), twist = 0):
    
    min_n_holes = np.min((n_holes_x,n_holes_y))

#     xx = scale*(np.arange(n_holes_x)-n_holes_x/2+0.5)/size+0.5
#     yy = scale*(np.arange(n_holes_y)-n_holes_y/2+0.5)/size+0.5
    xx = (np.arange(n_holes_x)-n_holes_x/2+0.5)*d_x+0.5
    yy = (np.arange(n_holes_y)-n_holes_y/2+0.5)*d_y+0.5
    cx,cy = np.meshgrid(xx,yy)
    
    cx = cx.reshape(n_holes_x*n_holes_y)
    cy = cy.reshape(n_holes_x*n_holes_y)
    c = np.vstack((cx,cy)) # hole coordinate

    s_xx = (-1)**np.arange(n_holes_x)
    s_yy = (-1)**np.arange(n_holes_y)
    sgn_x,sgn_y = np.meshgrid(s_xx,s_yy)
    sgn = sgn_x*sgn_y
    sgn = sgn.reshape(n_holes_x*n_holes_y)
    theta = np.pi*(sgn/2)*freq + phase # hole orientation
    theta = theta + (np.random.rand(len(theta))-0.5)*twist
    
    return(c, theta)

# %% [markdown]
# ## Generate holes

# %% [markdown]
# ### define parameters

# %%
A = np.array([1.0,0.25,0.01])
margin = 0.2

# %% [markdown]
# ### preview tools

# %%
# arrange the tools
size = 4
c, theta = arrange_array(5, 3, 1/size, 1/size, freq = 1/2, phase = np.pi/4)

# define tools
n_phi = 60
phi = np.arange(n_phi+1)/n_phi*2*np.pi
scale = 1/size/2*(1-margin)

r = np.zeros((n_phi+1))
v = np.zeros((2,n_phi+1))
for i in range(len(A)):
    ri = np.cos(2*(i)*phi)*A[i]
    vi = np.array([np.cos(phi), np.sin(phi)])*ri
    v = v+vi
    r = r+ri

r_square_mean = np.mean(r**2)
r_mean = np.mean(r)
v = v/np.sqrt(r_square_mean)*r_mean
#     v = v/np.sum(np.abs(A))
v = v*scale

# plot arranged tools
fig, ax = plt.subplots(1, 1, figsize=(6, 6))
for i in range(len(theta)):
    co, so = np.cos(theta[i]), np.sin(theta[i])
    Rotation = np.array(((co, -so), (so, co)))
    ri = Rotation@v
    ax.plot(ri[0,:] + c[0,i], ri[1,:] + c[1,i],'-',linewidth=3)
  
ax.plot([0,1,1,0,0],[0,0,1,1,0],'-k')
ax.set_xlim([-0.25,1.25])
ax.set_ylim([-0.25,1.25])
# Out:
# (-0.25, 1.25)

# %% [markdown]
# ## Generate Mesh

# %%
Lx = 1
Ly = 1

meshsize_min = 0.015
meshsize_max = 0.015

pygmsh_mesh_functions.hmeshmin = meshsize_min
pygmsh_mesh_functions.hmeshmax = meshsize_max

reset_geometry()

domain = add_polygon([(0, 0), (Lx, 0), (Lx, Ly), (0, Ly)])
X0 = np.array([0, 0])

#OPERATIONS ON DOMAIN
for i in range(len(theta)):
    co, so = np.cos(theta[i]), np.sin(theta[i])
    Rotation = np.array(((co, -so), (so, co)))
    
    polygon = (Rotation@v).T
    polygon = polygon[:-1]

    polygon_subdivide = subdivide_polygon(polygon, degree=2, preserve_ends=True)
    polygon_approx = approximate_polygon(polygon_subdivide,0.0025)
    polygon_shift = polygon_approx + c[:,i]

    hole_polygon(domain, polygon_shift)

#CREATE AND STORE MESH
sample_name = "test_loop_array_2fold_{}_{}_{}.xdmf".format(A[0],A[1],A[2])
out_dir = pathlib.Path("output_files")
out_dir.mkdir(parents=True, exist_ok=True)
mesh = create_fenics_mesh(mesh_path = out_dir / sample_name, verbose=True)
cell_type = mesh.cell_name()
with create_XDMFFile(out_dir / sample_name) as xf:
    xf.write(mesh)
    
plot(mesh)
len(mesh.coordinates())
# Out:
# Info    : Running '/home/fenics/.local/bin/gmsh -3 /tmp/tmpuh25qw0d.geo -format msh -bin -o /tmp/tmpv9xm00fy.msh' [Gmsh 4.9.5, 1 node, max. 1 thread]
# Info    : Started on Sat May 21 01:16:38 2022
# Info    : Reading '/tmp/tmpuh25qw0d.geo'...
# Info    : Done reading '/tmp/tmpuh25qw0d.geo'
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1766 (Line)
# Info    : [ 10%] Meshing curve 1767 (Line)
# Info    : [ 10%] Meshing curve 1768 (Line)
# Info    : [ 10%] Meshing curve 1769 (Line)
# Info    : [ 10%] Meshing curve 1770 (Line)
# Info    : [ 10%] Meshing curve 1771 (Line)
# Info    : [ 10%] Meshing curve 1772 (Line)
# Info    : [ 10%] Meshing curve 1773 (Line)
# Info    : [ 10%] Meshing curve 1774 (Line)
# Info    : [ 10%] Meshing curve 1775 (Line)
# Info    : [ 10%] Meshing curve 1776 (Line)
# Info    : [ 10%] Meshing curve 1777 (Line)
# Info    : [ 10%] Meshing curve 1778 (Line)
# Info    : [ 10%] Meshing curve 1779 (Line)
# Info    : [ 10%] Meshing curve 1780 (Line)
# Info    : [ 10%] Meshing curve 1781 (Line)
# Info    : [ 10%] Meshing curve 1782 (Line)
# Info    : [ 10%] Meshing curve 1783 (Line)
# Info    : [ 10%] Meshing curve 1784 (Line)
# Info    : [ 10%] Meshing curve 1785 (Line)
# Info    : [ 10%] Meshing curve 1786 (Line)
# Info    : [ 10%] Meshing curve 1787 (Line)
# Info    : [ 10%] Meshing curve 1788 (Line)
# Info    : [ 10%] Meshing curve 1789 (Line)
# Info    : [ 10%] Meshing curve 1790 (Line)
# Info    : [ 20%] Meshing curve 1791 (Line)
# Info    : [ 20%] Meshing curve 1792 (Line)
# Info    : [ 20%] Meshing curve 1793 (Line)
# Info    : [ 20%] Meshing curve 1794 (Line)
# Info    : [ 20%] Meshing curve 1795 (Line)
# Info    : [ 20%] Meshing curve 1796 (Line)
# Info    : [ 20%] Meshing curve 1797 (Line)
# Info    : [ 20%] Meshing curve 1798 (Line)
# Info    : [ 20%] Meshing curve 1799 (Line)
# Info    : [ 20%] Meshing curve 1800 (Line)
# Info    : [ 20%] Meshing curve 1801 (Line)
# Info    : [ 20%] Meshing curve 1802 (Line)
# Info    : [ 20%] Meshing curve 1803 (Line)
# Info    : [ 20%] Meshing curve 1804 (Line)
# Info    : [ 20%] Meshing curve 1805 (Line)
# Info    : [ 20%] Meshing curve 1806 (Line)
# Info    : [ 20%] Meshing curve 1807 (Line)
# Info    : [ 20%] Meshing curve 1808 (Line)
# Info    : [ 20%] Meshing curve 1809 (Line)
# Info    : [ 20%] Meshing curve 1810 (Line)
# Info    : [ 20%] Meshing curve 1811 (Line)
# Info    : [ 20%] Meshing curve 1812 (Line)
# Info    : [ 20%] Meshing curve 1813 (Line)
# Info    : [ 20%] Meshing curve 1814 (Line)
# Info    : [ 30%] Meshing curve 1815 (Line)
# Info    : [ 30%] Meshing curve 1816 (Line)
# Info    : [ 30%] Meshing curve 1817 (Line)
# Info    : [ 30%] Meshing curve 1818 (Line)
# Info    : [ 30%] Meshing curve 1819 (Line)
# Info    : [ 30%] Meshing curve 1820 (Line)
# Info    : [ 30%] Meshing curve 1821 (Line)
# Info    : [ 30%] Meshing curve 1822 (Line)
# Info    : [ 30%] Meshing curve 1823 (Line)
# Info    : [ 30%] Meshing curve 1824 (Line)
# Info    : [ 30%] Meshing curve 1825 (Line)
# Info    : [ 30%] Meshing curve 1826 (Line)
# Info    : [ 30%] Meshing curve 1827 (Line)
# Info    : [ 30%] Meshing curve 1828 (Line)
# Info    : [ 30%] Meshing curve 1829 (Line)
# Info    : [ 30%] Meshing curve 1830 (Line)
# Info    : [ 30%] Meshing curve 1831 (Line)
# Info    : [ 30%] Meshing curve 1832 (Line)
# Info    : [ 30%] Meshing curve 1833 (Line)
# Info    : [ 30%] Meshing curve 1834 (Line)
# Info    : [ 30%] Meshing curve 1835 (Line)
# Info    : [ 30%] Meshing curve 1836 (Line)
# Info    : [ 30%] Meshing curve 1837 (Line)
# Info    : [ 30%] Meshing curve 1838 (Line)
# Info    : [ 40%] Meshing curve 1839 (Line)
# Info    : [ 40%] Meshing curve 1840 (Line)
# Info    : [ 40%] Meshing curve 1841 (Line)
# Info    : [ 40%] Meshing curve 1842 (Line)
# Info    : [ 40%] Meshing curve 1843 (Line)
# Info    : [ 40%] Meshing curve 1844 (Line)
# Info    : [ 40%] Meshing curve 1845 (Line)
# Info    : [ 40%] Meshing curve 1846 (Line)
# Info    : [ 40%] Meshing curve 1847 (Line)
# Info    : [ 40%] Meshing curve 1848 (Line)
# Info    : [ 40%] Meshing curve 1849 (Line)
# Info    : [ 40%] Meshing curve 1850 (Line)
# Info    : [ 40%] Meshing curve 1851 (Line)
# Info    : [ 40%] Meshing curve 1852 (Line)
# Info    : [ 40%] Meshing curve 1853 (Line)
# Info    : [ 40%] Meshing curve 1854 (Line)
# Info    : [ 40%] Meshing curve 1855 (Line)
# Info    : [ 40%] Meshing curve 1856 (Line)
# Info    : [ 40%] Meshing curve 1857 (Line)
# Info    : [ 40%] Meshing curve 1858 (Line)
# Info    : [ 40%] Meshing curve 1859 (Line)
# Info    : [ 40%] Meshing curve 1860 (Line)
# Info    : [ 40%] Meshing curve 1861 (Line)
# Info    : [ 40%] Meshing curve 1862 (Line)
# Info    : [ 50%] Meshing curve 1863 (Line)
# Info    : [ 50%] Meshing curve 1864 (Line)
# Info    : [ 50%] Meshing curve 1865 (Line)
# Info    : [ 50%] Meshing curve 1866 (Line)
# Info    : [ 50%] Meshing curve 1867 (Line)
# Info    : [ 50%] Meshing curve 1868 (Line)
# Info    : [ 50%] Meshing curve 1869 (Line)
# Info    : [ 50%] Meshing curve 1870 (Line)
# Info    : [ 50%] Meshing curve 1871 (Line)
# Info    : [ 50%] Meshing curve 1872 (Line)
# Info    : [ 50%] Meshing curve 1873 (Line)
# Info    : [ 50%] Meshing curve 1874 (Line)
# Info    : [ 50%] Meshing curve 1875 (Line)
# Info    : [ 50%] Meshing curve 1876 (Line)
# Info    : [ 50%] Meshing curve 1877 (Line)
# Info    : [ 50%] Meshing curve 1878 (Line)
# Info    : [ 50%] Meshing curve 1879 (Line)
# Info    : [ 50%] Meshing curve 1880 (Line)
# Info    : [ 50%] Meshing curve 1881 (Line)
# Info    : [ 50%] Meshing curve 1882 (Line)
# Info    : [ 50%] Meshing curve 1883 (Line)
# Info    : [ 50%] Meshing curve 1884 (Line)
# Info    : [ 50%] Meshing curve 1885 (Line)
# Info    : [ 50%] Meshing curve 1886 (Line)
# Info    : [ 50%] Meshing curve 1887 (Line)
# Info    : [ 60%] Meshing curve 1888 (Line)
# Info    : [ 60%] Meshing curve 1889 (Line)
# Info    : [ 60%] Meshing curve 1890 (Line)
# Info    : [ 60%] Meshing curve 1891 (Line)
# Info    : [ 60%] Meshing curve 1892 (Line)
# Info    : [ 60%] Meshing curve 1893 (Line)
# Info    : [ 60%] Meshing curve 1894 (Line)
# Info    : [ 60%] Meshing curve 1895 (Line)
# Info    : [ 60%] Meshing curve 1896 (Line)
# Info    : [ 60%] Meshing curve 1897 (Line)
# Info    : [ 60%] Meshing curve 1898 (Line)
# Info    : [ 60%] Meshing curve 1899 (Line)
# Info    : [ 60%] Meshing curve 1900 (Line)
# Info    : [ 60%] Meshing curve 1901 (Line)
# Info    : [ 60%] Meshing curve 1902 (Line)
# Info    : [ 60%] Meshing curve 1903 (Line)
# Info    : [ 60%] Meshing curve 1904 (Line)
# Info    : [ 60%] Meshing curve 1905 (Line)
# Info    : [ 60%] Meshing curve 1906 (Line)
# Info    : [ 60%] Meshing curve 1907 (Line)
# Info    : [ 60%] Meshing curve 1908 (Line)
# Info    : [ 60%] Meshing curve 1909 (Line)
# Info    : [ 60%] Meshing curve 1910 (Line)
# Info    : [ 60%] Meshing curve 1911 (Line)
# Info    : [ 70%] Meshing curve 1912 (Line)
# Info    : [ 70%] Meshing curve 1913 (Line)
# Info    : [ 70%] Meshing curve 1914 (Line)
# Info    : [ 70%] Meshing curve 1915 (Line)
# Info    : [ 70%] Meshing curve 1916 (Line)
# Info    : [ 70%] Meshing curve 1917 (Line)
# Info    : [ 70%] Meshing curve 1918 (Line)
# Info    : [ 70%] Meshing curve 1919 (Line)
# Info    : [ 70%] Meshing curve 1920 (Line)
# Info    : [ 70%] Meshing curve 1921 (Line)
# Info    : [ 70%] Meshing curve 1922 (Line)
# Info    : [ 70%] Meshing curve 1923 (Line)
# Info    : [ 70%] Meshing curve 1924 (Line)
# Info    : [ 70%] Meshing curve 1925 (Line)
# Info    : [ 70%] Meshing curve 1926 (Line)
# Info    : [ 70%] Meshing curve 1927 (Line)
# Info    : [ 70%] Meshing curve 1928 (Line)
# Info    : [ 70%] Meshing curve 1929 (Line)
# Info    : [ 70%] Meshing curve 1930 (Line)
# Info    : [ 70%] Meshing curve 1931 (Line)
# Info    : [ 70%] Meshing curve 1932 (Line)
# Info    : [ 70%] Meshing curve 1933 (Line)
# Info    : [ 70%] Meshing curve 1934 (Line)
# Info    : [ 70%] Meshing curve 1935 (Line)
# Info    : [ 80%] Meshing curve 1936 (Line)
# Info    : [ 80%] Meshing curve 1937 (Line)
# Info    : [ 80%] Meshing curve 1938 (Line)
# Info    : [ 80%] Meshing curve 1939 (Line)
# Info    : [ 80%] Meshing curve 1940 (Line)
# Info    : [ 80%] Meshing curve 1941 (Line)
# Info    : [ 80%] Meshing curve 1942 (Line)
# Info    : [ 80%] Meshing curve 1943 (Line)
# Info    : [ 80%] Meshing curve 1944 (Line)
# Info    : [ 80%] Meshing curve 1945 (Line)
# Info    : [ 80%] Meshing curve 1946 (Line)
# Info    : [ 80%] Meshing curve 1947 (Line)
# Info    : [ 80%] Meshing curve 1948 (Line)
# Info    : [ 80%] Meshing curve 1949 (Line)
# Info    : [ 80%] Meshing curve 1950 (Line)
# Info    : [ 80%] Meshing curve 1951 (Line)
# Info    : [ 80%] Meshing curve 1952 (Line)
# Info    : [ 80%] Meshing curve 1953 (Line)
# Info    : [ 80%] Meshing curve 1954 (Line)
# Info    : [ 80%] Meshing curve 1955 (Line)
# Info    : [ 80%] Meshing curve 1956 (Line)
# Info    : [ 80%] Meshing curve 1957 (Line)
# Info    : [ 80%] Meshing curve 1958 (Line)
# Info    : [ 80%] Meshing curve 1959 (Line)
# Info    : [ 90%] Meshing curve 1960 (Line)
# Info    : [ 90%] Meshing curve 1961 (Line)
# Info    : [ 90%] Meshing curve 1962 (Line)
# Info    : [ 90%] Meshing curve 1963 (Line)
# Info    : [ 90%] Meshing curve 1964 (Line)
# Info    : [ 90%] Meshing curve 1965 (Line)
# Info    : [ 90%] Meshing curve 1966 (Line)
# Info    : [ 90%] Meshing curve 1967 (Line)
# Info    : [ 90%] Meshing curve 1968 (Line)
# Info    : [ 90%] Meshing curve 1969 (Line)
# Info    : [ 90%] Meshing curve 1970 (Line)
# Info    : [ 90%] Meshing curve 1971 (Line)
# Info    : [ 90%] Meshing curve 1972 (Line)
# Info    : [ 90%] Meshing curve 1973 (Line)
# Info    : [ 90%] Meshing curve 1974 (Line)
# Info    : [ 90%] Meshing curve 1975 (Line)
# Info    : [ 90%] Meshing curve 1976 (Line)
# Info    : [ 90%] Meshing curve 1977 (Line)
# Info    : [ 90%] Meshing curve 1978 (Line)
# Info    : [ 90%] Meshing curve 1979 (Line)
# Info    : [ 90%] Meshing curve 1980 (Line)
# Info    : [ 90%] Meshing curve 1981 (Line)
# Info    : [ 90%] Meshing curve 1982 (Line)
# Info    : [ 90%] Meshing curve 1983 (Line)
# Info    : [100%] Meshing curve 1984 (Line)
# Info    : [100%] Meshing curve 1985 (Line)
# Info    : [100%] Meshing curve 1986 (Line)
# Info    : [100%] Meshing curve 1987 (Line)
# Info    : [100%] Meshing curve 1988 (Line)
# Info    : [100%] Meshing curve 1989 (Line)
# Info    : [100%] Meshing curve 1990 (Line)
# Info    : [100%] Meshing curve 1991 (Line)
# Info    : [100%] Meshing curve 1992 (Line)
# Info    : [100%] Meshing curve 1993 (Line)
# Info    : [100%] Meshing curve 1994 (Line)
# Info    : [100%] Meshing curve 1995 (Line)
# Info    : [100%] Meshing curve 1996 (Line)
# Info    : [100%] Meshing curve 1997 (Line)
# Info    : [100%] Meshing curve 1998 (Line)
# Info    : [100%] Meshing curve 1999 (Line)
# Info    : [100%] Meshing curve 2000 (Line)
# Info    : [100%] Meshing curve 2001 (Line)
# Info    : [100%] Meshing curve 2002 (Line)
# Info    : [100%] Meshing curve 2003 (Line)
# Info    : [100%] Meshing curve 2004 (Line)
# Info    : [100%] Meshing curve 2005 (Line)
# Info    : [100%] Meshing curve 2006 (Line)
# Info    : [100%] Meshing curve 2007 (Line)
# Info    : Done meshing 1D (Wall 0.0329459s, CPU 0.032806s)
# Info    : Meshing 2D...
# Info    : Meshing surface 6 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.195744s, CPU 0.195741s)
# Info    : Meshing 3D...
# Info    : Done meshing 3D (Wall 2.36001e-05s, CPU 2.5e-05s)
# Info    : 5518 nodes 11294 elements
# Info    : Writing '/tmp/tmpv9xm00fy.msh'...
# Info    : Done writing '/tmp/tmpv9xm00fy.msh'
# Info    : Stopped on Sat May 21 01:16:39 2022 (From start: Wall 0.439404s, CPU 0.620274s)
# 5518
